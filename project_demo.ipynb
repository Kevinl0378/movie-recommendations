# %%
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
print(f"Keras version: {keras.__version__}")
print(f"Using backend: {keras.backend.backend()}")
# Out:
# Keras version: 3.10.0
# Using backend: torch

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU available: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    print("Training will be significantly faster on GPU!")
else:
    device = torch.device("cpu")
    print("⚠ No GPU detected - using CPU")
    print("  Training will be slower. Consider using Google Colab or Kaggle Kernel for free GPU access.")
# Out:
# GPU available: Tesla T4
# Memory: 15.83 GB
# Training will be significantly faster on GPU!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import random
from collections import Counter


import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
ratings = pd.read_csv('ratings.csv')
ratings.nunique()
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
n_users = int(ratings.nunique()['userId'])
n_movies = int(ratings.nunique()['movieId'])

# %%
unique_movie_ids = ratings['movieId'].unique()
movie_idx = {mid:idx+1 for idx, mid in enumerate(unique_movie_ids)}

# %%
ratings['movieId'] = ratings['movieId'].map(movie_idx)
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s', utc=True)

# %%
num_movies = ratings['movieId'].nunique()
vocab_size = num_movies + 1  # padding index 0

# %% [markdown]
# ### Preprocessing

# %%
movies = pd.read_csv('movies.csv')

all_genres = set()
for g in movies['genres']:
    all_genres.update(g.split('|'))
all_genres.discard('(no genres listed)')
genre_list = sorted(list(all_genres))
genre_map = {g: i for i, g in enumerate(genre_list)}
num_genres = len(genre_list) # Should be 19


# Lookup table (row 0 is for padding), should have shape (9725, 19)
movie_genre_matrix = np.zeros((len(movie_idx) + 1, num_genres))

for mid, row in movies.iterrows():
    og_id = row['movieId']
    if og_id in movie_idx:
      mapped_id = movie_idx[og_id]
      genres = row['genres'].split('|')
      for genre_id in genres:
          if genre_id in genre_map:
              movie_genre_matrix[mapped_id, genre_map[genre_id]] = 1.0

print("Shape:", movie_genre_matrix.shape)
# Out:
# Shape: (9725, 19)

# %% [markdown]
# ### Data Loader

# %%
look_back = 12

ratings_sorted = ratings.sort_values(by=['userId', 'timestamp'])
user_grouped = ratings_sorted.groupby('userId')

user_sequences = {}
for user_id, group in user_grouped:
    movie_ids = group['movieId'].values
    rating_vals = group['rating'].values / 5.0 # Noramlization
    user_sequences[user_id] = list(zip(movie_ids, rating_vals))

# %%
# Sliding windows
def create_windows(seq, look_back=look_back):
    X_ids, X_genres, X_ratings, y_ids = [], [], [], []

    for i in range(len(seq) - look_back):
        window = seq[i : i + look_back]
        target = seq[i + look_back]

        window_ids = [item[0] for item in window]
        window_ratings = [[item[1]] for item in window]
        window_genres = []
        for movie_id in window_ids:
            if movie_id == 0:
                window_genres.append(np.zeros(num_genres))
            else:
                window_genres.append(movie_genre_matrix[movie_id])

        X_ids.append(window_ids)
        X_genres.append(window_genres)
        X_ratings.append(window_ratings)
        y_ids.append(target[0])

    return X_ids, X_genres, X_ratings, y_ids

# %%
train_ids, train_genres, train_ratings, train_y = [], [], [], []
val_ids,   val_genres,   val_ratings,   val_y   = [], [], [], []
test_ids,  test_genres,  test_ratings,  test_y  = [], [], [], []

for uid, seq in user_sequences.items():

    # Test set
    test_target = seq[-1]
    window_test = seq[-(look_back+1):-1]
    test_ids.append([x[0] for x in window_test])
    test_ratings.append([[x[1]] for x in window_test])
    test_genres.append([movie_genre_matrix[x[0]] if x[0]!=0 else np.zeros(num_genres) for x in window_test])
    test_y.append(test_target[0])

    # Validation set
    val_target = seq[-2]
    window_val = seq[-(look_back+2):-2]
    val_ids.append([x[0] for x in window_val])
    val_ratings.append([[x[1]] for x in window_val])
    val_genres.append([movie_genre_matrix[x[0]] if x[0]!=0 else np.zeros(num_genres) for x in window_val])
    val_y.append(val_target[0])

    # Training set
    train_seq = seq[:-2]
    ids, genres, ratings, y = create_windows(train_seq)
    train_ids.extend(ids)
    train_genres.extend(genres)
    train_ratings.extend(ratings)
    train_y.extend(y)

X_train, y_train = [np.array(train_ids), np.array(train_genres), np.array(train_ratings)], np.array(train_y)
X_val, y_val = [np.array(val_ids), np.array(val_genres), np.array(val_ratings)], np.array(val_y)
X_test, y_test = [np.array(test_ids), np.array(test_genres), np.array(test_ratings)], np.array(test_y)

print(f"Train Shapes: movieIds: {X_train[0].shape}, Genres: {X_train[1].shape}, Ratings: {X_train[2].shape}")
# Out:
# Train Shapes: movieIds: (92296, 12), Genres: (92296, 12, 19), Ratings: (92296, 12, 1)

# %% [markdown]
# ### Model Definition

# %%
# Re-define variables
look_back = 12
vocab_size = len(movie_idx) + 1
num_genres = 19

movie_input = Input(shape=(look_back,))
movie_emb = layers.Embedding(input_dim=vocab_size, output_dim=128)(movie_input)

genre_input = Input(shape=(look_back, num_genres))
genre_feat = layers.Dense(64, activation='relu')(genre_input)

rating_input = Input(shape=(look_back, 1))
rating_feat = layers.Dense(32, activation='relu')(rating_input)

# Incorporate context into LSTM model
context = layers.Concatenate(axis=2)([movie_emb, genre_feat, rating_feat])

lstm = layers.LSTM(256, recurrent_dropout=0.2, dropout=0.0)(context)
x = layers.Dense(512, activation='relu')(lstm)
x = layers.Dropout(0.1)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(128, activation='relu')(x)
output = layers.Dense(vocab_size, activation='softmax')(x) # Softmax


model_v2 = Model(inputs=[movie_input, genre_input, rating_input], outputs=output)

model_v2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy',
                 metrics=['sparse_categorical_accuracy',
                          tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top5'),
                          tf.keras.metrics.SparseTopKCategoricalAccuracy(k=10, name='top10')])

model_v2.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9       │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_10      │ (None, 12, 19)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_11      │ (None, 12, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 12, 128)   │  1,244,800 │ input_layer_9[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 12, 64)    │      1,280 │ input_layer_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 12, 32)    │         64 │ input_layer_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 12, 224)   │          0 │ embedding_3[0][0… │
# │ (Concatenate)       │                   │            │ dense_18[0][0],   │
# │                     │                   │            │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 256)       │    492,544 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 512)       │    131,584 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 512)       │          0 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 256)       │    131,328 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256)       │          0 │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │     32,896 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 9725)      │  1,254,525 │ dense_22[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,289,021 (12.55 MB)
#  Trainable params: 3,289,021 (12.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Model Training

# %%
# EARLY STOP
early_stop = EarlyStopping(monitor='val_top10', patience=5, mode='max', restore_best_weights=True)

history_v2 = model_v2.fit(x=X_train, y=y_train, batch_size=256, epochs=30, validation_data=(X_val, y_val), callbacks=[early_stop],verbose=1)
result_v2 = model_v2.evaluate(X_test, y_test, batch_size=256, verbose=0)

loss_v2 = round(result_v2[0], 4)
top1_v2 = round(result_v2[1] * 100, 4)
top5_v2 = round(result_v2[2] * 100, 4)
top10_v2 = round(result_v2[3] * 100, 4)

print(f"Test Loss: {loss_v2}")
print(f"Top-1 Accuracy: {top1_v2}%")
print(f"Top-5 Accuracy: {top5_v2}%")
print(f"Top-10 Accuracy: {top10_v2}%")
# Out:
# Epoch 1/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - loss: 8.3824 - sparse_categorical_accuracy: 0.0018 - top10: 0.0175 - top5: 0.0092 - val_loss: 8.0564 - val_sparse_categorical_accuracy: 0.0000e+00 - val_top10: 0.0246 - val_top5: 0.0115
# Epoch 2/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - loss: 7.8846 - sparse_categorical_accuracy: 0.0027 - top10: 0.0222 - top5: 0.0120 - val_loss: 7.9259 - val_sparse_categorical_accuracy: 0.0016 - val_top10: 0.0262 - val_top5: 0.0082
# Epoch 3/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 7.5908 - sparse_categorical_accuracy: 0.0031 - top10: 0.0340 - top5: 0.0172 - val_loss: 7.6615 - val_sparse_categorical_accuracy: 0.0049 - val_top10: 0.0459 - val_top5: 0.0197
# Epoch 4/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 7.2722 - sparse_categorical_accuracy: 0.0057 - top10: 0.0499 - top5: 0.0269 - val_loss: 7.6463 - val_sparse_categorical_accuracy: 0.0131 - val_top10: 0.0574 - val_top5: 0.0344
# Epoch 5/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 7.0042 - sparse_categorical_accuracy: 0.0078 - top10: 0.0650 - top5: 0.0342 - val_loss: 7.6128 - val_sparse_categorical_accuracy: 0.0082 - val_top10: 0.0738 - val_top5: 0.0393
# Epoch 6/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 6.8118 - sparse_categorical_accuracy: 0.0101 - top10: 0.0745 - top5: 0.0415 - val_loss: 7.7022 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0623 - val_top5: 0.0393
# Epoch 7/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 6.6343 - sparse_categorical_accuracy: 0.0118 - top10: 0.0873 - top5: 0.0488 - val_loss: 7.7421 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0787 - val_top5: 0.0492
# Epoch 8/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - loss: 6.4574 - sparse_categorical_accuracy: 0.0132 - top10: 0.0998 - top5: 0.0574 - val_loss: 7.9039 - val_sparse_categorical_accuracy: 0.0131 - val_top10: 0.0770 - val_top5: 0.0508
# Epoch 9/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 6.2820 - sparse_categorical_accuracy: 0.0156 - top10: 0.1139 - top5: 0.0659 - val_loss: 7.9902 - val_sparse_categorical_accuracy: 0.0066 - val_top10: 0.0705 - val_top5: 0.0377
# Epoch 10/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 6.1254 - sparse_categorical_accuracy: 0.0186 - top10: 0.1288 - top5: 0.0759 - val_loss: 8.1636 - val_sparse_categorical_accuracy: 0.0098 - val_top10: 0.0869 - val_top5: 0.0459
# Epoch 11/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 5.9668 - sparse_categorical_accuracy: 0.0233 - top10: 0.1408 - top5: 0.0842 - val_loss: 8.2667 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0672 - val_top5: 0.0361
# Epoch 12/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 5.7990 - sparse_categorical_accuracy: 0.0272 - top10: 0.1637 - top5: 0.0971 - val_loss: 8.3954 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0820 - val_top5: 0.0459
# Epoch 13/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - loss: 5.6570 - sparse_categorical_accuracy: 0.0295 - top10: 0.1780 - top5: 0.1097 - val_loss: 8.5732 - val_sparse_categorical_accuracy: 0.0098 - val_top10: 0.0787 - val_top5: 0.0459
# Epoch 14/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 5.4976 - sparse_categorical_accuracy: 0.0366 - top10: 0.2049 - top5: 0.1273 - val_loss: 8.7261 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0902 - val_top5: 0.0525
# Epoch 15/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 5.3700 - sparse_categorical_accuracy: 0.0392 - top10: 0.2200 - top5: 0.1391 - val_loss: 8.8551 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0639 - val_top5: 0.0361
# Epoch 16/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 5.2158 - sparse_categorical_accuracy: 0.0494 - top10: 0.2495 - top5: 0.1618 - val_loss: 8.9528 - val_sparse_categorical_accuracy: 0.0082 - val_top10: 0.0738 - val_top5: 0.0393
# Epoch 17/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 5.0773 - sparse_categorical_accuracy: 0.0561 - top10: 0.2736 - top5: 0.1804 - val_loss: 9.1423 - val_sparse_categorical_accuracy: 0.0082 - val_top10: 0.0738 - val_top5: 0.0410
# Epoch 18/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - loss: 4.9581 - sparse_categorical_accuracy: 0.0660 - top10: 0.2945 - top5: 0.1976 - val_loss: 9.3145 - val_sparse_categorical_accuracy: 0.0115 - val_top10: 0.0639 - val_top5: 0.0410
# Epoch 19/30
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 4.8442 - sparse_categorical_accuracy: 0.0722 - top10: 0.3195 - top5: 0.2136 - val_loss: 9.4704 - val_sparse_categorical_accuracy: 0.0066 - val_top10: 0.0639 - val_top5: 0.0377
# Test Loss: 8.7814
# Top-1 Accuracy: 0.9836%
# Top-5 Accuracy: 4.4262%
# Top-10 Accuracy: 7.377%

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# ## Negative Sampling

# %%
def negative_sampling(model, X_test, y_test, k_values=range(1,11), num_negatives=100):

    random.seed(3)

    all_probs = model.predict(X_test, batch_size=256, verbose=0)
    freqs = {k: 0 for k in k_values}
    num_users = len(y_test)

    X_test_ids = X_test[0]

    for i in range(num_users):
        target_item = y_test[i]
        user_history_set = set(X_test_ids[i])
        user_history_set.add(target_item)

        # Negative sampling
        negatives = set()
        while len(negatives) < num_negatives:
            neg_id = random.randint(1, vocab_size-1)
            if neg_id not in user_history_set:
                negatives.add(neg_id)

        candidates = [target_item] + list(negatives)
        scores = all_probs[i][candidates]
        ranked_indices = np.argsort(scores)[::-1]
        rank = np.where(ranked_indices == 0)[0][0] + 1

        for k in k_values:
            if rank <= k:
                freqs[k] += 1

    results = {}
    for k in k_values:
        HR = round((freqs[k] / num_users)*100, 2)
        results[k] = HR
        if k % 5 == 0:
          print(f"Hit Ratio@{k}: {HR}%")

    return results

results_negative_sampled = negative_sampling(model_v2, X_test, y_test)
# Out:
# Hit Ratio@5: 53.61%
# Hit Ratio@10: 69.02%

# %%
ks = results_negative_sampled.keys()
HRs = [results_negative_sampled[k] for k in ks]

plt.figure()
plt.plot(ks, HRs, marker='o')
plt.xlabel("K")
plt.ylabel("HR@K (%)")
plt.title("Hit Ratio @ K")
plt.ylim(bottom=15)
plt.show()
